# %% [markdown]
# ## Python Fundamentals 2025: Домашнее задание 1

# %% [markdown]
# ### 1
# Приветственное сообщение
#
# Создайте программу, которая выведет строки "Hi!" и "Hello!" на разных строках.
#
# Пример вывода:
#
# Hi!
#
# Hello!

# %%
print("Hi!\nHello!")
# Out:
# Hi!
# Hello!

# %%
# или
print("Hi!")
print("Hello!")
# Out:
# Hi!
# Hello!

# %%
# или ещё так, используя переменные и данные:
a = 'Hi!'
b = 'Hello!'

print(a)
print(b)
# Out:
# Hi!
# Hello!

# %% [markdown]
# ### 2
# Именное приветствие
#
# Создайте программу, которая попросит пользователя ввести его имя, а затем выведет фразу: "Hello, <Name>" на новой строке.
#
# Пример вывода:
#
# Hello, Name

# %%
name_user = input("Enter your Name")
print("Hello, " + name_user)

# %%
name = input(" Ввeдите ваше имя:  ")
print("Hello,", name)

# %%
# найти ошибку
name = input

print("Hello + name")
# Out:
# ghf
# Hello + name

# %% [markdown]
# ## Python Fundamentals 2025: Домашнее задание 2

# %% [markdown]
# ## 1
# Числовая цепочка
#
# Напишите программу, которая выводит числа от 1 до 5 включительно, разделяя их символами “---”. Используйте параметр sep.
#
# Пример вывода:
#
# 1---2---3---4---5

# %%
print(1, 2, 3, 4, 5, sep="---")
# Out:
# 1---2---3---4---5

# %%
print("1", "2", "3", "4", "5", sep="---")

# %% [markdown]
# ## 2
# Пробельные символы
#
# Напишите программу, которая выведет две строки: первая строка с табуляцией, вторая — на новой строке с помощью одного вызова print().
#
# Пример вывода:
#
#   Первая строка с табуляцией
#
# Вторая строка на новой строке

# %%
first_line = "\tstr1"
second_line = "\nstr2"
print(first_line, second_line)
# Out:
# 	str1
# str2

# %%
print("\tПервая строка с табуляцией\nВторая строка на новой строке")
# Out:
# 	Первая строка с табуляцией
# Вторая строка на новой строке

# %% [markdown]
# ## 3
# Текст в кавычках
#
# Напишите программу, которая выводит строку "Это файл "example.txt"". Выполните задачу несколькими способами.
#
# Пример вывода:
#
# Это файл "example.txt"

# %%
print("Это файл 'example.txt'")
print('Это файл "example.txt"')
# Out:
# Это файл 'example.txt'
# Это файл "example.txt"

# %%
print("Это файл \"example.txt\"")
# Out:
# Это файл "example.txt"

# %%
print('''Это файл "example.txt"''')
# Out:
# Это файл "example.txt"
